# %%
import pandas as pd

# %%
df = pd.read_csv("./data/charts.csv", nrows=1_000_000)

# %%
df["region"].value_counts()
# Out:
# region
# Argentina               20651
# Australia               20650
# Belgium                 20650
# Austria                 20627
# Brazil                  20622
#                         ...
# Saudi Arabia             2562
# Morocco                  1814
# Egypt                    1712
# United Arab Emirates     1485
# Andorra                  1145
# Name: count, Length: 67, dtype: int64

# %%
df.head(5)
# Out:
#                          title  rank        date  \
# 0      Chantaje (feat. Maluma)     1  2017-01-01
# 1  Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2   Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                       Safari     4  2017-01-01
# 4                  Shaky Shaky     5  2017-01-01
#
#                                   artist  \
# 0                                Shakira
# 1                           Ricky Martin
# 2                                   CNCO
# 3  J Balvin, Pharrell Williams, BIA, Sky
# 4                           Daddy Yankee
#
#                                                  url     region   chart  \
# 0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina  top200
# 1  https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina  top200
# 2  https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina  top200
# 3  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina  top200
# ...

# %%
df = df[df["region"] == "Poland"]

# %%
df = df[df["url"] == "https://open.spotify.com/track/4pdPtRcBmOSQDlJ3Fk945m"]

# %%
df.sort_values("date")
# Out:
#                   title  rank        date                   artist  \
# 6423    Let Me Love You     1  2017-01-01  DJ Snake, Justin Bieber
# 20575   Let Me Love You     4  2017-01-02  DJ Snake, Justin Bieber
# 46550   Let Me Love You     5  2017-01-03  DJ Snake, Justin Bieber
# 99787   Let Me Love You     5  2017-01-04  DJ Snake, Justin Bieber
# 159867  Let Me Love You     4  2017-01-05  DJ Snake, Justin Bieber
# ...                 ...   ...         ...                      ...
# 755608  Let Me Love You   158  2018-05-03  DJ Snake, Justin Bieber
# 814102  Let Me Love You   159  2018-05-04  DJ Snake, Justin Bieber
# 863132  Let Me Love You   151  2018-05-05  DJ Snake, Justin Bieber
# 893185  Let Me Love You   161  2018-05-06  DJ Snake, Justin Bieber
# 983533  Let Me Love You   179  2018-05-07  DJ Snake, Justin Bieber
#
#                                                       url  region   chart  \
# 6423    https://open.spotify.com/track/4pdPtRcBmOSQDlJ...  Poland  top200
# ...
